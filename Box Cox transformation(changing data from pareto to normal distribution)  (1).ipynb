# %%
# importing all important modules like
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
from scipy import stats   # this will be used for implementing box -cox function 

# first generating data which is non--normally distributed like
original_data=np.random.exponential(size=100000)

# now transforming this data to follow normal distribution like
fitted_data,fitted_alpha=stats.boxcox(original_data)

# now creating axes for plotting plots 
# fig,ax=plt.subplots(1,2)

# plotting original and fitted data using seaborn as

sns.displot(original_data,kind='kde',label='Non-Normal',color='red',ax=ax[0])

sns.displot(fitted_data,kind='kde',label='Normal',color='green',ax=ax[1])

# for adding legends to the plots 
plt.legend(loc='upper right')

# re-shaping the plots as
fig.set_figheight(5)
fig.set_figwidth(10)

# what is the value of alpha ?
print('the alpha value whuch is used for getting this transformation is=',fitted_alpha)
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try kdeplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\Dell\anaconda3\lib\site-packages\seaborn\distributions.py:2211: UserWarning: `displot` is a figure-level function and does not accept the ax= paramter. You may wish to try kdeplot.
#   warnings.warn(msg, UserWarning)
# the alpha value whuch is used for getting this transformation is= 0.26447013351158966

# %%
# now we can plot qq plot of fitted data to see wether it is normally distributed or not 
import pylab as py 
import statsmodels.api as sm 

sm.qqplot(fitted_data,line='45')
py.show()

# %%
# still the data is not normally distributed as it is away from the reference line boz the data original_data
# was not really a pareto data it was exponential data rather

# %%
# now we will generate pareto data and than apply boxcox transformation to get  normally distributed
# data after boxcox transformation 

import numpy as np
import matplotlib.pyplot as plt
from scipy import stats 
import pylab 

x_m=10
size=100000
alpha=15
samples=(np.random.pareto(alpha,size)+1)*x_m
stats.probplot(samples,dist='pareto',sparams=(15,10),plot=pylab)
plt.show()

# %%
# now we can see that the data after transformation is normally distributed so we can say that the 
# data before transformation was 'pareto distributed data'

# %%
# now see the bell curve for  the data after transformation and before transformation as

# before transformation which was 'pareto'
sm.qqplot(samples,line='45')
py.show()

# after transfromation 'normal'
sm.qqplot(stats.probplot(samples,dist='pareto',sparams=(15,10),plot=pylab),line='45')
py.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [27], in <cell line: 8>()
#       5 py.show()
#       7 # after transfromation 'normal'
# ----> 8 sm.qqplot(stats.probplot(samples,dist='pareto',sparams=(15,10),plot=pylab),line='45')
#       9 py.show()
#
# File ~\anaconda3\lib\site-packages\statsmodels\graphics\gofplots.py:688, in qqplot(data, dist, distargs, a, loc, scale, fit, line, ax, **plotkwargs)
#     581 def qqplot(
#     582     data,
#     583     dist=stats.norm,
#    (...)
#     591     **plotkwargs,
#     592 ):
#     593     """
#     594     Q-Q plot of the quantiles of x versus the quantiles/ppf of a distribution.
#     595
#    (...)
#     686     .. plot:: plots/graphics_gofplots_qqplot.py
#     687     """
# --> 688     probplot = ProbPlot(
#     689         data, dist=dist, distargs=distargs, fit=fit, a=a, loc=loc, scale=scale
#     690     )
# ...

# %%
# it is confirmed from above plots the first one is for data following 'Pareto' and the second one is the 'normally' distributed data
